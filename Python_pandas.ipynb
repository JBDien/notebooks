# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dates = pd.date_range ('20150101', periods = 60)

# %%
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2015-01-01, ..., 2015-03-01]
# Length: 60, Freq: D, Timezone: None

# %%
df = pd.DataFrame(np.random.randn(60,4), index =dates, columns = list('abcd'))

# %%
df
# Out:
#                    a         b         c         d
# 2015-01-01 -0.281095  0.665149 -1.295902  0.963540
# 2015-01-02  1.428536 -1.308773  1.588679  0.649714
# 2015-01-03  0.077664  1.076150  0.381771 -0.022685
# 2015-01-04 -0.627838  1.135704  0.876651 -0.615393
# 2015-01-05 -0.386898  0.091182 -1.806446 -0.843335
# 2015-01-06 -0.082324  1.099377 -0.264850  1.871698
# 2015-01-07 -1.676200  0.009634  0.155931 -1.705741
# 2015-01-08  0.669017  0.826892  1.214986  2.729793
# 2015-01-09 -1.828261  0.204446  0.304460  1.225411
# 2015-01-10 -0.103767 -0.045551 -0.921638  1.604404
# 2015-01-11  0.273209 -0.462926 -0.592232 -0.384417
# 2015-01-12 -0.397305  0.399900  0.021416  0.863399
# 2015-01-13  0.820865 -1.270556  0.065918 -1.732040
# 2015-01-14  0.613992  0.001566  1.690365 -1.269227
# 2015-01-15  0.605970  0.308084  0.472701 -1.178471
# 2015-01-16  0.014623 -1.555786  0.235006  0.542670
# 2015-01-17 -0.939298  1.136346 -1.399335  1.144381
# ...

# %%
df.describe()
# Out:
#                a          b          c          d
# count  60.000000  60.000000  60.000000  60.000000
# mean   -0.056186  -0.094028   0.088688  -0.048217
# std     0.872759   1.062895   1.001419   0.991169
# min    -2.498999  -3.107326  -2.183015  -2.578294
# 25%    -0.636500  -0.821123  -0.513023  -0.501527
# 50%    -0.043972  -0.050531   0.110924   0.042386
# 75%     0.607504   0.667680   0.779811   0.552786
# max     1.678235   2.200547   1.913636   2.729793

# %%
df.to_csv('df2.csv')

# %%
pd.read_csv('Contenu_A1_2015.csv').describe()
# Out:
#           n_ligne       act_fin   marge_gest  var_marge_gest  marge_cible  \
# count  234.000000    234.000000   234.000000      234.000000   234.000000
# mean   117.500000   5853.380206   142.665413       23.819822   196.782113
# std     67.694165  11167.607508   767.637847      255.422294   676.334241
# min      1.000000      0.000000 -5962.999730    -2604.821160 -3268.999730
# 25%     59.250000    896.187437   -25.482308       -2.696810    -0.127205
# 50%    117.500000   3334.726900    29.008880        4.650950    40.547450
# 75%    175.750000   5956.813960   199.644755       55.118902   245.338957
# max    234.000000  99999.999990  4986.363680     1118.178550  4986.363680
#
#        var_marge_cible   act_cum_n-1     act_cum_n   act_cum_n+1  \
# count       234.000000    234.000000    234.000000    234.000000
# mean         42.972945   4079.342672   5416.663061   5951.426517
# std         221.305771   9976.611547  10586.202045  11148.225849
# ...

# %%
df.describe()
# Out:
#                a          b          c          d
# count  60.000000  60.000000  60.000000  60.000000
# mean   -0.058228  -0.072674   0.057093   0.137794
# std     0.879032   0.896334   1.002447   1.083667
# min    -1.925823  -1.680979  -1.964184  -2.714807
# 25%    -0.640879  -0.689876  -0.628187  -0.376940
# 50%    -0.058449   0.018204   0.081362   0.233206
# 75%     0.599140   0.380024   0.718819   0.766726
# max     1.860424   1.861039   3.029267   2.812541

# %%
pd.read_csv('essai.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-32-a9e75799b88f> in <module>()
# ----> 1 pd.read_csv('essai.csv')
#
# ...
